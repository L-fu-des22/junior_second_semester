# %%
import cv2
import numpy as np
from PIL import Image
def show_cvimg(im):
    return Image.fromarray(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))

im_path =  r'E:\Junior_second_semester\SDM378_CV\week2\lab2\images\pic1.png'
src = cv2.imread(im_path)
show_cvimg(src)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x2C81D657130>
